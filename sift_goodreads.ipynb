# %%
import pandas

# %%
goodreads = pandas.read_csv('goodreads_library_export.csv')

# %%
goodreads.head()
# Out:
#     Book Id                                              Title  \
# 0  12757626                                   Naive Set Theory
# 1  13539191              Three Parts Dead (Craft Sequence, #1)
# 2  16059411              Two Serpents Rise (Craft Sequence #2)
# 3   8855321                      Leviathan Wakes (Expanse, #1)
# 4     36232  The Elusive Quest for Growth: Economists' Adve...
#
#              Author         Author l-f Additional Authors           ISBN  \
# 0    Paul R. Halmos    Halmos, Paul R.                NaN  ="1614271313"
# 1     Max Gladstone     Gladstone, Max                NaN  ="0765333104"
# 2     Max Gladstone     Gladstone, Max                NaN  ="0765333120"
# 3  James S.A. Corey  Corey, James S.A.                NaN  ="1841499889"
# 4  William Easterly  Easterly, William                NaN  ="0262550423"
#
#              ISBN13  My Rating  Average Rating           Publisher ...   \
# 0  ="9781614271314"          0            4.14  Martino Fine Books ...
# ...
